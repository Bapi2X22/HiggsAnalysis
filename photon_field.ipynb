# %%
import numpy as np
import awkward as ak
import uproot
import matplotlib.pyplot as plt

# %%
fname = "1487e377-20cd-4a73-97de-b5e019014dfd.root"

# %%
with uproot.open(fname, timeout=120) as Hfile:
    print(Hfile.keys())
    Tree = Hfile["Events"]  # can access TTrees by name
    Events = Tree.arrays(library="ak", how="zip")
# Out:
# ['tag;1', 'Events;1', 'LuminosityBlocks;1', 'Runs;1', 'MetaData;1', 'ParameterSets;1']

# %%
Events.fields
# Out:
# ['run',
#  'luminosityBlock',
#  'event',
#  'bunchCrossing',
#  'HTXS_njets25',
#  'HTXS_njets30',
#  'HTXS_stage1_1_cat_pTjet25GeV',
#  'HTXS_stage1_1_cat_pTjet30GeV',
#  'HTXS_stage1_1_fine_cat_pTjet25GeV',
#  'HTXS_stage1_1_fine_cat_pTjet30GeV',
#  'HTXS_stage1_2_cat_pTjet25GeV',
#  'HTXS_stage1_2_cat_pTjet30GeV',
#  'HTXS_stage1_2_fine_cat_pTjet25GeV',
#  'HTXS_stage1_2_fine_cat_pTjet30GeV',
#  'HTXS_stage_0',
#  'HTXS_stage_1_pTjet25',
#  'HTXS_stage_1_pTjet30',
#  'HTXS_Higgs_pt',
#  'HTXS_Higgs_y',
#  'BeamSpot_type',
#  'BeamSpot_sigmaZ',
#  'BeamSpot_sigmaZError',
#  'BeamSpot_z',
#  'BeamSpot_zError',
#  'nboostedTau',
#  'CaloMET_phi',
#  'CaloMET_pt',
#  'CaloMET_sumEt',
#  'ChsMET_phi',
#  'ChsMET_pt',
#  'ChsMET_sumEt',
#  'nCorrT1METJet',
#  'DeepMETResolutionTune_phi',
#  'DeepMETResolutionTune_pt',
#  'DeepMETResponseTune_phi',
#  'DeepMETResponseTune_pt',
#  'nElectron',
#  'nFatJet',
#  'nFsrPhoton',
#  'nGenJetAK8',
#  'nGenJet',
#  'nGenPart',
#  'nGenProton',
# ...

# %%
from coffea.nanoevents import NanoEventsFactory, NanoAODSchema, schemas

dir(NanoAODSchema)

# # Open the file with the NanoAODSchema
# events = NanoEventsFactory.from_root(
#     "1487e377-20cd-4a73-97de-b5e019014dfd.root",
#     treepath="Events",
#     schemaclass=NanoAODSchema,
#     schema=schemas.NanoAODSchema.v13
# ).events()

# # Check the Rho attributes available
# print(dir(events.Rho))

# # Access fixedGridRhoAll
# rho = events.Rho.fixedGridRhoAll

# # Example: shape per event
# print(rho)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_build_collections',
#  'all_cross_references',
#  'behavior',
#  'form',
#  'mixins',
#  'nested_index_items',
#  'nested_items',
#  'special_items',
#  'v5',
#  'v6',
#  'v7',
#  'warn_missing_crossrefs']

# %%
events.Rho
# Out:
# <NanoCollectionArray [{fixedGridRhoAll: 19.6, ... ] type='32026 * struct[["fixed...'>
